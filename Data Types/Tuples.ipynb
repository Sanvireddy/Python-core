# %% [markdown]
# ``Tuples``
# - Immutable
# - It is not possible to assign to the individual items of a tuple, however it is possible to create tuples which contain mutable objects, such as lists.

# %%
t = 'hey','hi',9
print(t)

# singleton tupe
s = 'hey', # note the trailing comma
print(s)

tupleList = [1,2,3,4],[5,6,7,8]
tupleList[0][0] = 0
print(tupleList)
# this will raise an error
# Out:
# ('hey', 'hi', 9)
# ('hey',)
# ([0, 2, 3, 4], [5, 6, 7, 8])
