# %% [markdown]
# `OrderedDict` is like a regular dict but has some special capabilities such as tracking the insertion order but from Python 3.7, regular dict also has this capacity

# %%
from collections import OrderedDict
ordered_dict = OrderedDict()
ordered_dict['b'] = 4
ordered_dict['a'] = 2
ordered_dict['c'] = 3
print(ordered_dict)
# Out:
# OrderedDict([('b', 4), ('a', 2), ('c', 3)])
